# %%
# tes memahami cara kerja numpy dan matplotlib

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import numpy as np
X = np.array([[1, 2], [11, 4], [1, 0],
              [10, 2], [10, 4], [10, 0]])
# mencoba akses array X
X[0]

# %%
# mencoba akses elemen tertentu
X[0,1]

# %%
# mencoba akses kolom pertama
X[:,0]

# %%
kmeans = KMeans(n_clusters=2, random_state=0).fit(X)
# melihat objek kmeans
kmeans

# %%
label = kmeans.labels_
# melihat objek label
label

# %%
label[0]

# %%
clusters = kmeans.fit_predict(X)
#X["label"] = clusters
# melihat objek clusters
clusters

# %%
#plt.scatter('a', 'b', c='c', s='d', data=data)
plt.scatter(X[:,0][label==0], X[:,1][label==0], c='red')
plt.scatter(X[:,0][label==1], X[:,1][label==1], c='blue')
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()
